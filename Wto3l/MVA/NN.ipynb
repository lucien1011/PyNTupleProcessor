# %%
import sys
sys.path = ['', '/home/nikmenendez/.local/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/share/overrides/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/cmssw/CMSSW_9_4_4/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/cmssw/CMSSW_9_4_4/lib/slc6_amd64_gcc630', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/coral/CORAL_2_3_21-fmblme4/slc6_amd64_gcc630/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/coral/CORAL_2_3_21-fmblme4/slc6_amd64_gcc630/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/professor2/2.2.1-fmblme5/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/pyqt/4.11.4-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/sherpa/2.2.4-fmblme2/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/rivet/2.5.4/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python-ldap/2.4.10-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-matplotlib/1.5.2-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/sip/4.17-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/llvm/4.0.1/lib64/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-sqlalchemy/1.1.4-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-lint/0.25.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-dxr/1.0-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-cx-oracle/5.2.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-numpy/1.12.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/frontier_client/2.8.20-fmblme/python/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/das_client/v03.01.00-fmblme/bin', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/xrootd/4.6.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/yoda/1.6.7/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/lcg/root/6.10.08/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/pyminuit2/0.0.1-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-PyYAML/3.11-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pygithub/1.23.0-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pip/9.0.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-dablooms/0.9.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme4/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs/6.0-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/professor/1.4.0-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/dbs-client/DBS_2_1_9-fmblme/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/dbs-client/DBS_2_1_9-fmblme/lib/DBSAPI', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/cvs2git/5419-fmblme/lib', '/blue/avery/nikmenendez/Wto3l/Analyzer2/UF-PyNTupleRunner/Wto3l', '/blue/avery/nikmenendez/Wto3l/Analyzer2/UF-PyNTupleRunner', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-sqlalchemy/1.1.4-fmblme/lib/python2.7/site-packages/SQLAlchemy-1.1.4-py2.7-linux-x86_64.egg', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-numpy/1.12.1-fmblme/lib/python2.7/site-packages/numpy-1.12.1-py2.7-linux-x86_64.egg', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python27.zip', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/plat-linux2', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-tk', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-old', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-dynload', '/home/nikmenendez/.local/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/site-packages']

# %%
import os
os.environ['KERAS_BACKEND']='tensorflow'

from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.optimizers import SGD
from tensorflow.python.keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten, LeakyReLU, ReLU
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.optimizers import TFOptimizer

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import pandas as pd
import numpy as np
import uproot
#from sklearn.metrics import roc_curve, auc
#from sklearn.preprocessing import StandardScaler
#import matplotlib
#from matplotlib import pyplot as plt
#import pickle

# from keras.models import Sequential, Model
# from keras.optimizers import SGD
# from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten, LeakyReLU
# from keras.utils import np_utils

#from Utils.DeltaR import deltaR

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Import files and select variables

input_files = ['/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root']
treename = 'passedEvents'

vars_in = ['Lep1_pt','Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
           'Lep2_pt','Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
           'Lep3_pt','Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
           'met','met_phi','dR12','dR13','dR23','c0','c1','c2','c3']

vars_test = ['Lep1_pt','Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
           'Lep2_pt','Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
           'Lep3_pt','Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
           'met','met_phi','dR12','dR13','dR23']

vars_check = ['c0','c1','c2','c3']

#vars_in = list(set(vars_in))

print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]
# Out:
# ... Opening input files:
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root

# %%
#Shuffle DF and split into training and testing

signal = shuffle(signal)
signal = signal.reset_index(drop=True)
signal_train, signal_test = train_test_split(signal, test_size=0.33, random_state=123456)

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('dense_model.h5', monitor='val_loss', 
                                  verbose=0, save_best_only=True, 
                                  save_weights_only=False, mode='auto', 
                                  period=1)

#print signal_train[vars_check]
# Out:
# Using TensorFlow backend.

# %%
#Create model

inputs = Input(shape=(len(vars_test),), name = 'input')
#x = Dropout(.1, name = 'input_dropout_.2')(inputs)
x = Dense(32, name = 'hidden1')(inputs)
x = LeakyReLU(.0, name = 'LeakyReLU1_.0')(x)
x = Dense(64, name = 'hidden2')(x)
x = LeakyReLU(.0, name = 'LeakyReLU2_.0')(x)
#x = Dropout(.2, name = 'hidden2_dropout_.4')(x)
outputs = Dense(4, name = 'output', activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# model = Sequential()
# model.add(Dense(64, input_dim=len(vars_test), activation='relu'))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(4, activation='softmax'))
# # Compile model
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 20)]              0
# _________________________________________________________________
# hidden1 (Dense)              (None, 32)                672
# _________________________________________________________________
# LeakyReLU1_.0 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# hidden2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# LeakyReLU2_.0 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# output (Dense)               (None, 4)                 260
# =================================================================
# Total params: 3,044
# Trainable params: 3,044
# Non-trainable params: 0
# _________________________________________________________________

# %%
history = model.fit(signal_train[vars_test],
                    signal_train[vars_check],
                    epochs=100,
                    batch_size=256,
                    verbose=1,
                    callbacks=[early_stopping], 
                    validation_split=0.25)
# Out:
# Train on 307239 samples, validate on 102413 samples
# Epoch 1/100
# 307239/307239 [==============================] - 2s 8us/sample - loss: 0.8464 - categorical_accuracy: 0.5653 - val_loss: 0.6707 - val_categorical_accuracy: 0.6016
# Epoch 2/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6763 - categorical_accuracy: 0.6003 - val_loss: 0.6866 - val_categorical_accuracy: 0.6099
# Epoch 3/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6675 - categorical_accuracy: 0.6053 - val_loss: 0.6569 - val_categorical_accuracy: 0.6179
# Epoch 4/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6629 - categorical_accuracy: 0.6082 - val_loss: 0.6489 - val_categorical_accuracy: 0.6203
# Epoch 5/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6560 - categorical_accuracy: 0.6133 - val_loss: 0.6473 - val_categorical_accuracy: 0.6231
# Epoch 6/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6516 - categorical_accuracy: 0.6172 - val_loss: 0.6455 - val_categorical_accuracy: 0.6209
# Epoch 7/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6483 - categorical_accuracy: 0.6197 - val_loss: 0.6415 - val_categorical_accuracy: 0.6269
# Epoch 8/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6456 - categorical_accuracy: 0.6219 - val_loss: 0.6448 - val_categorical_accuracy: 0.6206
# Epoch 9/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6445 - categorical_accuracy: 0.6217 - val_loss: 0.6446 - val_categorical_accuracy: 0.6237
# Epoch 10/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6427 - categorical_accuracy: 0.6238 - val_loss: 0.6427 - val_categorical_accuracy: 0.6167
# Epoch 11/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6416 - categorical_accuracy: 0.6243 - val_loss: 0.6389 - val_categorical_accuracy: 0.6256
# Epoch 12/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6410 - categorical_accuracy: 0.6261 - val_loss: 0.6374 - val_categorical_accuracy: 0.6324
# Epoch 13/100
# 307239/307239 [==============================] - 2s 8us/sample - loss: 0.6394 - categorical_accuracy: 0.6275 - val_loss: 0.6350 - val_categorical_accuracy: 0.6295
# Epoch 14/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6391 - categorical_accuracy: 0.6277 - val_loss: 0.6396 - val_categorical_accuracy: 0.6307
# Epoch 15/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6379 - categorical_accuracy: 0.6298 - val_loss: 0.6354 - val_categorical_accuracy: 0.6320
# Epoch 16/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6376 - categorical_accuracy: 0.6293 - val_loss: 0.6330 - val_categorical_accuracy: 0.6331
# Epoch 17/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6374 - categorical_accuracy: 0.6298 - val_loss: 0.6389 - val_categorical_accuracy: 0.6306
# Epoch 18/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6372 - categorical_accuracy: 0.6303 - val_loss: 0.6359 - val_categorical_accuracy: 0.6315
# Epoch 19/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6362 - categorical_accuracy: 0.6308 - val_loss: 0.6340 - val_categorical_accuracy: 0.6329
# Epoch 20/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6361 - categorical_accuracy: 0.6309 - val_loss: 0.6340 - val_categorical_accuracy: 0.6315
# Epoch 21/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6353 - categorical_accuracy: 0.6308 - val_loss: 0.6334 - val_categorical_accuracy: 0.6349
# Epoch 22/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6354 - categorical_accuracy: 0.6318 - val_loss: 0.6313 - val_categorical_accuracy: 0.6359
# Epoch 23/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6344 - categorical_accuracy: 0.6335 - val_loss: 0.6311 - val_categorical_accuracy: 0.6375
# Epoch 24/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6340 - categorical_accuracy: 0.6335 - val_loss: 0.6304 - val_categorical_accuracy: 0.6363
# Epoch 25/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6339 - categorical_accuracy: 0.6336 - val_loss: 0.6289 - val_categorical_accuracy: 0.6383
# Epoch 26/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6336 - categorical_accuracy: 0.6339 - val_loss: 0.6326 - val_categorical_accuracy: 0.6373
# Epoch 27/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6329 - categorical_accuracy: 0.6346 - val_loss: 0.6293 - val_categorical_accuracy: 0.6400
# Epoch 28/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6325 - categorical_accuracy: 0.6340 - val_loss: 0.6287 - val_categorical_accuracy: 0.6392
# Epoch 29/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6325 - categorical_accuracy: 0.6346 - val_loss: 0.6308 - val_categorical_accuracy: 0.6346
# Epoch 30/100
# 307239/307239 [==============================] - 2s 8us/sample - loss: 0.6322 - categorical_accuracy: 0.6348 - val_loss: 0.6306 - val_categorical_accuracy: 0.6349
# Epoch 31/100
# 307239/307239 [==============================] - 2s 8us/sample - loss: 0.6319 - categorical_accuracy: 0.6352 - val_loss: 0.6302 - val_categorical_accuracy: 0.6339
# Epoch 32/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6319 - categorical_accuracy: 0.6354 - val_loss: 0.6294 - val_categorical_accuracy: 0.6359
# Epoch 33/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6314 - categorical_accuracy: 0.6360 - val_loss: 0.6320 - val_categorical_accuracy: 0.6334
# Epoch 34/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6312 - categorical_accuracy: 0.6363 - val_loss: 0.6278 - val_categorical_accuracy: 0.6402
# Epoch 35/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6310 - categorical_accuracy: 0.6364 - val_loss: 0.6311 - val_categorical_accuracy: 0.6322
# Epoch 36/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6306 - categorical_accuracy: 0.6363 - val_loss: 0.6261 - val_categorical_accuracy: 0.6427
# Epoch 37/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6304 - categorical_accuracy: 0.6366 - val_loss: 0.6272 - val_categorical_accuracy: 0.6414
# Epoch 38/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6304 - categorical_accuracy: 0.6379 - val_loss: 0.6257 - val_categorical_accuracy: 0.6427
# Epoch 39/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6298 - categorical_accuracy: 0.6378 - val_loss: 0.6296 - val_categorical_accuracy: 0.6365
# Epoch 40/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6297 - categorical_accuracy: 0.6374 - val_loss: 0.6302 - val_categorical_accuracy: 0.6332
# Epoch 41/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6297 - categorical_accuracy: 0.6375 - val_loss: 0.6257 - val_categorical_accuracy: 0.6420
# Epoch 42/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6294 - categorical_accuracy: 0.6382 - val_loss: 0.6266 - val_categorical_accuracy: 0.6413
# Epoch 43/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6285 - categorical_accuracy: 0.6388 - val_loss: 0.6270 - val_categorical_accuracy: 0.6401
# Epoch 44/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6289 - categorical_accuracy: 0.6389 - val_loss: 0.6270 - val_categorical_accuracy: 0.6427
# Epoch 45/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6288 - categorical_accuracy: 0.6388 - val_loss: 0.6254 - val_categorical_accuracy: 0.6423
# Epoch 46/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6285 - categorical_accuracy: 0.6387 - val_loss: 0.6262 - val_categorical_accuracy: 0.6424
# Epoch 47/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6285 - categorical_accuracy: 0.6391 - val_loss: 0.6296 - val_categorical_accuracy: 0.6379
# Epoch 48/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6282 - categorical_accuracy: 0.6396 - val_loss: 0.6243 - val_categorical_accuracy: 0.6431
# Epoch 49/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6281 - categorical_accuracy: 0.6394 - val_loss: 0.6257 - val_categorical_accuracy: 0.6427
# Epoch 50/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6283 - categorical_accuracy: 0.6400 - val_loss: 0.6272 - val_categorical_accuracy: 0.6426
# Epoch 51/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6276 - categorical_accuracy: 0.6407 - val_loss: 0.6236 - val_categorical_accuracy: 0.6437
# Epoch 52/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6274 - categorical_accuracy: 0.6395 - val_loss: 0.6265 - val_categorical_accuracy: 0.6442
# Epoch 53/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6279 - categorical_accuracy: 0.6402 - val_loss: 0.6251 - val_categorical_accuracy: 0.6412
# Epoch 54/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6275 - categorical_accuracy: 0.6402 - val_loss: 0.6280 - val_categorical_accuracy: 0.6388
# Epoch 55/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6276 - categorical_accuracy: 0.6397 - val_loss: 0.6283 - val_categorical_accuracy: 0.6414
# Epoch 56/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6271 - categorical_accuracy: 0.6404 - val_loss: 0.6254 - val_categorical_accuracy: 0.6419
# Epoch 57/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6275 - categorical_accuracy: 0.6394 - val_loss: 0.6249 - val_categorical_accuracy: 0.6444
# Epoch 58/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6273 - categorical_accuracy: 0.6408 - val_loss: 0.6238 - val_categorical_accuracy: 0.6454
# Epoch 59/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6268 - categorical_accuracy: 0.6408 - val_loss: 0.6244 - val_categorical_accuracy: 0.6437
# Epoch 60/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6269 - categorical_accuracy: 0.6411 - val_loss: 0.6248 - val_categorical_accuracy: 0.6430
# Epoch 61/100
# 307239/307239 [==============================] - 2s 7us/sample - loss: 0.6269 - categorical_accuracy: 0.6410 - val_loss: 0.6237 - val_categorical_accuracy: 0.6447

# %%
results = model.evaluate(signal_test[vars_test], signal_test[vars_check])
print results
# Out:
# 201770/201770 [==============================] - 3s 16us/sample - loss: 0.6267 - categorical_accuracy: 0.6412
# [0.6267101763426421, 0.6411607]

# %%
predictions = model.predict(signal_test[vars_test])

# %%
predictions[0]
# Out:
# array([2.0576472e-04, 6.2393188e-01, 3.7566862e-01, 1.9384154e-04],
#       dtype=float32)

# %%
print signal_test[vars_check].iloc[0]
# Out:
# c0    0
# c1    1
# c2    0
# c3    0
# Name: 436381, dtype: int32

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# plot loss vs epoch
plt.figure(figsize=(15,10))
ax = plt.subplot(2, 2, 1)
ax.plot(history.history['loss'], label='loss')
ax.plot(history.history['val_loss'], label='val_loss')
ax.legend(loc="upper right")
ax.set_xlabel('epoch')
ax.set_ylabel('loss')

# plot accuracy vs epoch
ax = plt.subplot(2, 2, 2)
ax.plot(history.history['categorical_accuracy'], label='acc')
ax.plot(history.history['val_categorical_accuracy'], label='val_acc')
ax.legend(loc="upper left")
ax.set_xlabel('epoch')
ax.set_ylabel('acc')

# %%
#Save model
model.save("ZSelector_model.h5")

# %%
q=0

from tensorflow.python.keras.models import load_model
ZSelector = load_model('ZSelector_model.h5')
prediction_0 = ZSelector.predict(signal_test[vars_test])
print prediction_0[q]
print signal_test[vars_check].iloc[q]

max_guess = 0
guess_2nd = 0
guess_slot = 0
guess_2nd_slot = 0
for i in range(len(prediction_0[q])):
    if prediction_0[q][i] > max_guess:
        guess_2nd = max_guess
        guess_2nd_slot = guess_slot
        max_guess = prediction_0[q][i]
        guess_slot = i
        print "Guess = " + str(guess_slot) + ", 2nd Guess = " + str(guess_2nd_slot)
    elif prediction_0[q][i] > guess_2nd:
        guess_2nd = prediction_0[q][i]
        guess_slot = i

print "Guess = " + str(guess_slot) + ", 2nd Guess = " + str(guess_2nd_slot)
# Out:
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# [2.0576472e-04 6.2393188e-01 3.7566862e-01 1.9384154e-04]
# c0    0
# c1    1
# c2    0
# c3    0
# Name: 436381, dtype: int32
# Guess = 0, 2nd Guess = 0
# Guess = 1, 2nd Guess = 0
# Guess = 2, 2nd Guess = 0

# %%
#from tensorflow.python.keras.models import save_weight, to_json
# model.save_weights("ZSelector_weights.h5")
# model_json = model.to_json()
# with open('ZSelector_model.json', "w") as json_file:
#     json_file.write(model_json)
# json_file.close()

# %%
input_files = [#'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

vars_in = ['Lep1_pt','Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
           'Lep2_pt','Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
           'Lep3_pt','Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
           'met','met_phi','dR12','dR13','dR23','c0','c1','c2','c3']

vars_test = ['Lep1_pt','Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
           'Lep2_pt','Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
           'Lep3_pt','Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
           'met','met_phi','dR12','dR13','dR23']

vars_check = ['c0','c1','c2','c3']

#vars_in = list(set(vars_in))

print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]
# Out:
# ... Opening input files:
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root
# Opening file:  /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root

# %%
from tensorflow.python.keras.models import load_model
ZSelector = load_model('ZSelector_model.h5')

# %%
results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print results
# Out:
# 343067/343067 [==============================] - 6s 17us/sample - loss: 0.5459 - categorical_accuracy: 0.7331
# [0.5458612889952716, 0.7330813]

# %%
#print signal['c3'].iloc[0]
#prediction_0 = ZSelector.predict(signal[vars_test])
#print prediction_0

# %%
correct_events = 0.
total_events = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(prediction_0)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: correct_events+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: correct_events+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: correct_events+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: correct_events+=1
    total_events+=1
    
print 'Accuracy = %f' % (correct_events/total_events)
# Out:
# Accuracy = 0.733081
