# %%
import sys
sys.path = ['', '/home/nikmenendez/.local/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/share/overrides/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/cmssw/CMSSW_9_4_4/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/cmssw/CMSSW_9_4_4/lib/slc6_amd64_gcc630', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/coral/CORAL_2_3_21-fmblme4/slc6_amd64_gcc630/python', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/coral/CORAL_2_3_21-fmblme4/slc6_amd64_gcc630/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/professor2/2.2.1-fmblme5/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/pyqt/4.11.4-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/sherpa/2.2.4-fmblme2/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/rivet/2.5.4/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python-ldap/2.4.10-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-matplotlib/1.5.2-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/sip/4.17-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/llvm/4.0.1/lib64/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-sqlalchemy/1.1.4-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-lint/0.25.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-dxr/1.0-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-cx-oracle/5.2.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-numpy/1.12.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/frontier_client/2.8.20-fmblme/python/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/das_client/v03.01.00-fmblme/bin', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/xrootd/4.6.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/yoda/1.6.7/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/lcg/root/6.10.08/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/pyminuit2/0.0.1-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-PyYAML/3.11-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pygithub/1.23.0-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pip/9.0.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-dablooms/0.9.1-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs_depscipy/3.0-fmblme4/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-pippkgs/6.0-fmblme/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/professor/1.4.0-fmblme3/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/dbs-client/DBS_2_1_9-fmblme/lib', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/cms/dbs-client/DBS_2_1_9-fmblme/lib/DBSAPI', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/cvs2git/5419-fmblme/lib', '/blue/avery/nikmenendez/Wto3l/Analyzer2/UF-PyNTupleRunner/Wto3l', '/blue/avery/nikmenendez/Wto3l/Analyzer2/UF-PyNTupleRunner', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-sqlalchemy/1.1.4-fmblme/lib/python2.7/site-packages/SQLAlchemy-1.1.4-py2.7-linux-x86_64.egg', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/py2-numpy/1.12.1-fmblme/lib/python2.7/site-packages/numpy-1.12.1-py2.7-linux-x86_64.egg', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python27.zip', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/plat-linux2', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-tk', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-old', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/lib-dynload', '/home/nikmenendez/.local/lib/python2.7/site-packages', '/cvmfs/cms.cern.ch/slc6_amd64_gcc630/external/python/2.7.11-fmblme/lib/python2.7/site-packages']

# %%
import os
os.environ['KERAS_BACKEND']='tensorflow'

from tensorflow.python.keras.models import Sequential, Model
from tensorflow.python.keras.optimizers import SGD
from tensorflow.python.keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten, LeakyReLU, ReLU
from tensorflow.python.keras.utils import np_utils
from tensorflow.python.keras.optimizers import TFOptimizer

# %%
from sklearn.metrics import mean_squared_error
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
import pandas as pd
import numpy as np
import uproot
from __future__ import division
#from sklearn.metrics import roc_curve, auc
#from sklearn.preprocessing import StandardScaler
#import matplotlib
#from matplotlib import pyplot as plt
#import pickle

# from keras.models import Sequential, Model
# from keras.optimizers import SGD
# from keras.layers import Input, Activation, Dense, Convolution2D, MaxPooling2D, Dropout, Flatten, LeakyReLU
# from keras.utils import np_utils

#from Utils.DeltaR import deltaR

from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>"))
# Out:
# <style>.container { width:100% !important; }</style>

# %%
#Import files and select variables

input_files = ['/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/2017/MVA/WZTo3LNu_TuneCP5_13TeV-amcatnloFXFX-pythia8_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/2017/MVA/DYJetsToLL_M-10to50_TuneCP5_13TeV-madgraphMLM-pythia8_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/2017/MVA/DYJetsToLL_M-50_TuneCP5_13TeV-madgraphMLM-pythia8_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/2017/MVA/TTJets_DiLept_TuneCP5_13TeV-madgraphMLM-pythia8_PS.root',
               ]
treename = 'passedEvents'

# vars_in = ['Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
#            'Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
#            'Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
#            'met','met_phi','dR12','dR13','dR23','c0','c1','c2','c3']

vars_test = ['Lep1_pt','Lep1_eta','Lep1_phi','Lep1_iso','Lep1_id',
             'Lep2_pt','Lep2_eta','Lep2_phi','Lep2_iso','Lep2_id',
             'Lep3_pt','Lep3_eta','Lep3_phi','Lep3_iso','Lep3_id',
             'met','met_phi','dR12','dR13','dR23']

vars_check = ['c0','c1','c2','c3']

vars_in = vars_test + vars_check

#vars_in = list(set(vars_in))

print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)
weights = [len(signal.index)] * len(signal.index)
for w in range(len(weights)):
    weights[w] = 5191.0/weights[w]
signal['Weights'] = weights
#signal = signal.head(29741)
print "Opening file: %s with %i events" % (input_files[0], len(signal.index))

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    weights = [len(temp_sig.index)] * len(temp_sig.index)
    for w in range(len(weights)):
        weights[w] = 5191.0/weights[w]
    temp_sig['Weights'] = weights
    #temp_sig = temp_sig.head(29741)
    print "Opening file: %s with %i events" % (input_files[i],len(temp_sig.index))
    signal = signal.append(temp_sig)
    
#print signal[vars_in]
# Out:
# ... Opening input files:
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root with 29741 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root with 38838 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root with 58547 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root with 82107 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root with 89694 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root with 41259 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root with 41161 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root with 58809 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root with 83014 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root with 88252 events
# Opening file: /cmsuf/data/store/user/t2/users/nikmenendez/skimmed/2017/MVA/WZTo3LNu_TuneCP5_13TeV-amcatnloFXFX-pythia8_PS.root with 5191 events

# %%
# Normalize Features

def min_max_scaling(df):
    # copy the dataframe
    df_norm = df.copy()
    # Define min and max array
    mins = np.array([20.000065,-2.399986,-3.141562,0.000000,-13.000000,10.000033,-2.399970,-3.141574,0.000000,-13.000000,5.000017,-2.399923,-3.141588,0.000000,-13.000000,0.028749,-3.141591,0.006013,0.007271,0.008307,0.000000,0.000000,0.000000,0.000000,0.000000])
    maxs = np.array([1742.620117,2.400000,3.141587,4.511298,13.000000,602.987305,2.399974,3.141591,9.888725,13.000000,135.678162,2.399995,3.141589,40.849213,13.000000,1406.858643,3.141580,5.080047,4.880805,5.028722,1.000000,1.000000,1.000000,1.000000,1.000000])
    #mins = np.array([-2.399986,-3.141562,0.000000,-13.000000,-2.399970,-3.141574,0.000000,-13.000000,-2.399923,-3.141588,0.000000,-13.000000,0.028749,-3.141591,0.006013,0.007271,0.008307,0.000000,0.000000,0.000000,0.000000,0.000000])
    #maxs = np.array([2.400000,3.141587,4.511298,13.000000,2.399974,3.141591,9.888725,13.000000,2.399995,3.141589,40.849213,13.000000,1406.858643,3.141580,5.080047,4.880805,5.028722,1.000000,1.000000,1.000000,1.000000,1.000000])
    # apply min-max scaling
    i=0
    for column in df_norm.columns:
        if column == 'Weights': continue
        #print column + ": min = %f, max = %f" % (df_norm[column].min(),df_norm[column].max())
        #df_norm[column] = (df_norm[column] - df_norm[column].min()) / (df_norm[column].max() - df_norm[column].min())
        df_norm[column] = (df_norm[column] - mins[i]) / (maxs[i] - mins[i])
        i+=1
        
        
    return df_norm
    
# call the min_max_scaling function
signal = min_max_scaling(signal)

# for index, row in signal.iterrows():
#      row['Weights'] = 1.0 - row['Weights']

#print signal

# %%
#Shuffle DF and split into training and testing

signal = shuffle(signal)
signal = signal.reset_index(drop=True)
signal_train, signal_test = train_test_split(signal, test_size=0.33, random_state=123456)

# early stopping callback
from keras.callbacks import EarlyStopping
early_stopping = EarlyStopping(monitor='val_loss', patience=10)

# model checkpoint callback
# this saves our model architecture + parameters into dense_model.h5
from keras.callbacks import ModelCheckpoint
model_checkpoint = ModelCheckpoint('dense_model.h5', monitor='val_loss', 
                                  verbose=0, save_best_only=True, 
                                  save_weights_only=False, mode='auto', 
                                  period=1)

#print signal_train[vars_check]
# Out:
# Using TensorFlow backend.

# %%
#Create model

inputs = Input(shape=(len(vars_test),), name = 'input')
#x = Dropout(.1, name = 'input_dropout_.2')(inputs)
x = Dense(32, name = 'hidden1')(inputs)
x = LeakyReLU(.1, name = 'LeakyReLU1_.1')(x)
x = Dense(64, name = 'hidden2')(x)
x = LeakyReLU(.1, name = 'LeakyReLU2_.1')(x)
x = Dense(32, name = 'hidden3')(x)
x = LeakyReLU(.1, name = 'LeakyReLU3_.1')(x)
#x = Dropout(.1, name = 'hidden2_dropout_.1')(x)
outputs = Dense(4, name = 'output', activation='softmax')(x)

model = Model(inputs=inputs, outputs=outputs)
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# model = Sequential()
# model.add(Dense(64, input_dim=len(vars_test), activation='relu'))
# model.add(Dense(128, activation='relu'))
# model.add(Dense(4, activation='softmax'))
# # Compile model
# model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:1251: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input (InputLayer)           [(None, 20)]              0
# _________________________________________________________________
# hidden1 (Dense)              (None, 32)                672
# _________________________________________________________________
# LeakyReLU1_.1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# hidden2 (Dense)              (None, 64)                2112
# _________________________________________________________________
# LeakyReLU2_.1 (LeakyReLU)    (None, 64)                0
# _________________________________________________________________
# hidden3 (Dense)              (None, 32)                2080
# _________________________________________________________________
# LeakyReLU3_.1 (LeakyReLU)    (None, 32)                0
# _________________________________________________________________
# output (Dense)               (None, 4)                 132
# =================================================================
# Total params: 4,996
# Trainable params: 4,996
# Non-trainable params: 0
# _________________________________________________________________

# %%
# #Create model

# inputs = Input(shape=(len(vars_test),), name = 'input')
# #x = Dropout(.1, name = 'input_dropout_.2')(inputs)
# x = Dense(32, name = 'hidden1')(inputs)
# x = LeakyReLU(.1, name = 'LeakyReLU1_.1')(x)
# x = Dense(64, name = 'hidden2')(x)
# x = LeakyReLU(.1, name = 'LeakyReLU2_.1')(x)
# #x = Dense(32, name = 'hidden3')(x)
# #x = LeakyReLU(.1, name = 'LeakyReLU3_.1')(x)
# #x = Dropout(.2, name = 'hidden2_dropout_.4')(x)
# outputs = Dense(4, name = 'output', activation='softmax')(x)

# model = Model(inputs=inputs, outputs=outputs)
# model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['categorical_accuracy'])

# # model = Sequential()
# # model.add(Dense(64, input_dim=len(vars_test), activation='relu'))
# # model.add(Dense(128, activation='relu'))
# # model.add(Dense(4, activation='softmax'))
# # # Compile model
# # model.compile(loss='categorical_crossentropy', optimizer='adam', metrics=['accuracy'])

# model.summary()

# %%
history = model.fit(signal_train[vars_test],
                    signal_train[vars_check],
                    epochs=100,
                    batch_size=256,
                    sample_weight = signal_train['Weights'].values,
                    verbose=1,
                    #callbacks=[early_stopping], 
                    validation_split=0.25)
# Out:
# Train on 309847 samples, validate on 103283 samples
# Epoch 1/100
# 309847/309847 [==============================] - 3s 9us/sample - loss: 0.0676 - categorical_accuracy: 0.5412 - val_loss: 0.0628 - val_categorical_accuracy: 0.5611
# Epoch 2/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0622 - categorical_accuracy: 0.5737 - val_loss: 0.0624 - val_categorical_accuracy: 0.5836
# Epoch 3/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0613 - categorical_accuracy: 0.5876 - val_loss: 0.0612 - val_categorical_accuracy: 0.5633
# Epoch 4/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0599 - categorical_accuracy: 0.6018 - val_loss: 0.0594 - val_categorical_accuracy: 0.6078
# Epoch 5/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0583 - categorical_accuracy: 0.6120 - val_loss: 0.0580 - val_categorical_accuracy: 0.6111
# Epoch 6/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0571 - categorical_accuracy: 0.6208 - val_loss: 0.0578 - val_categorical_accuracy: 0.6139
# Epoch 7/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0559 - categorical_accuracy: 0.6326 - val_loss: 0.0557 - val_categorical_accuracy: 0.6406
# Epoch 8/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0549 - categorical_accuracy: 0.6466 - val_loss: 0.0547 - val_categorical_accuracy: 0.6515
# Epoch 9/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0542 - categorical_accuracy: 0.6570 - val_loss: 0.0542 - val_categorical_accuracy: 0.6759
# Epoch 10/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0536 - categorical_accuracy: 0.6651 - val_loss: 0.0536 - val_categorical_accuracy: 0.6674
# Epoch 11/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0532 - categorical_accuracy: 0.6712 - val_loss: 0.0533 - val_categorical_accuracy: 0.6793
# Epoch 12/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0528 - categorical_accuracy: 0.6739 - val_loss: 0.0530 - val_categorical_accuracy: 0.6799
# Epoch 13/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0525 - categorical_accuracy: 0.6788 - val_loss: 0.0528 - val_categorical_accuracy: 0.6772
# Epoch 14/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0522 - categorical_accuracy: 0.6810 - val_loss: 0.0525 - val_categorical_accuracy: 0.6870
# Epoch 15/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0520 - categorical_accuracy: 0.6825 - val_loss: 0.0522 - val_categorical_accuracy: 0.6761
# Epoch 16/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0516 - categorical_accuracy: 0.6847 - val_loss: 0.0521 - val_categorical_accuracy: 0.6986
# Epoch 17/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0514 - categorical_accuracy: 0.6870 - val_loss: 0.0516 - val_categorical_accuracy: 0.6837
# Epoch 18/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0512 - categorical_accuracy: 0.6894 - val_loss: 0.0521 - val_categorical_accuracy: 0.6735
# Epoch 19/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0510 - categorical_accuracy: 0.6903 - val_loss: 0.0516 - val_categorical_accuracy: 0.6887
# Epoch 20/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0508 - categorical_accuracy: 0.6926 - val_loss: 0.0518 - val_categorical_accuracy: 0.6628
# Epoch 21/100
# 309847/309847 [==============================] - 3s 8us/sample - loss: 0.0507 - categorical_accuracy: 0.6923 - val_loss: 0.0512 - val_categorical_accuracy: 0.7025
# Epoch 22/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0505 - categorical_accuracy: 0.6940 - val_loss: 0.0509 - val_categorical_accuracy: 0.6977
# Epoch 23/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0503 - categorical_accuracy: 0.6953 - val_loss: 0.0510 - val_categorical_accuracy: 0.6890
# Epoch 24/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0501 - categorical_accuracy: 0.6965 - val_loss: 0.0509 - val_categorical_accuracy: 0.6886
# Epoch 25/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0500 - categorical_accuracy: 0.6980 - val_loss: 0.0507 - val_categorical_accuracy: 0.6913
# Epoch 26/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0499 - categorical_accuracy: 0.6985 - val_loss: 0.0506 - val_categorical_accuracy: 0.6983
# Epoch 27/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0497 - categorical_accuracy: 0.6999 - val_loss: 0.0515 - val_categorical_accuracy: 0.6993
# Epoch 28/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0496 - categorical_accuracy: 0.7008 - val_loss: 0.0499 - val_categorical_accuracy: 0.7074
# Epoch 29/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0494 - categorical_accuracy: 0.7015 - val_loss: 0.0501 - val_categorical_accuracy: 0.6979
# Epoch 30/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0493 - categorical_accuracy: 0.7024 - val_loss: 0.0502 - val_categorical_accuracy: 0.7009
# Epoch 31/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0491 - categorical_accuracy: 0.7032 - val_loss: 0.0498 - val_categorical_accuracy: 0.6947
# Epoch 32/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0490 - categorical_accuracy: 0.7050 - val_loss: 0.0496 - val_categorical_accuracy: 0.7124
# Epoch 33/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0489 - categorical_accuracy: 0.7055 - val_loss: 0.0498 - val_categorical_accuracy: 0.6900
# Epoch 34/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0486 - categorical_accuracy: 0.7062 - val_loss: 0.0495 - val_categorical_accuracy: 0.7064
# Epoch 35/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0485 - categorical_accuracy: 0.7079 - val_loss: 0.0494 - val_categorical_accuracy: 0.7156
# Epoch 36/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0483 - categorical_accuracy: 0.7084 - val_loss: 0.0497 - val_categorical_accuracy: 0.7064
# Epoch 37/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0481 - categorical_accuracy: 0.7096 - val_loss: 0.0491 - val_categorical_accuracy: 0.7193
# Epoch 38/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0480 - categorical_accuracy: 0.7106 - val_loss: 0.0491 - val_categorical_accuracy: 0.7026
# Epoch 39/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0478 - categorical_accuracy: 0.7111 - val_loss: 0.0488 - val_categorical_accuracy: 0.7049
# Epoch 40/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0476 - categorical_accuracy: 0.7121 - val_loss: 0.0496 - val_categorical_accuracy: 0.6950
# Epoch 41/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0474 - categorical_accuracy: 0.7132 - val_loss: 0.0484 - val_categorical_accuracy: 0.7125
# Epoch 42/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0474 - categorical_accuracy: 0.7139 - val_loss: 0.0489 - val_categorical_accuracy: 0.7046
# Epoch 43/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0472 - categorical_accuracy: 0.7145 - val_loss: 0.0491 - val_categorical_accuracy: 0.7015
# Epoch 44/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0472 - categorical_accuracy: 0.7153 - val_loss: 0.0482 - val_categorical_accuracy: 0.7151
# Epoch 45/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0469 - categorical_accuracy: 0.7160 - val_loss: 0.0490 - val_categorical_accuracy: 0.7136
# Epoch 46/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0468 - categorical_accuracy: 0.7174 - val_loss: 0.0480 - val_categorical_accuracy: 0.7102
# Epoch 47/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0467 - categorical_accuracy: 0.7178 - val_loss: 0.0478 - val_categorical_accuracy: 0.7179
# Epoch 48/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0466 - categorical_accuracy: 0.7188 - val_loss: 0.0496 - val_categorical_accuracy: 0.6978
# Epoch 49/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0464 - categorical_accuracy: 0.7200 - val_loss: 0.0484 - val_categorical_accuracy: 0.7075
# Epoch 50/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0462 - categorical_accuracy: 0.7215 - val_loss: 0.0479 - val_categorical_accuracy: 0.7169
# Epoch 51/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0461 - categorical_accuracy: 0.7209 - val_loss: 0.0475 - val_categorical_accuracy: 0.7231
# Epoch 52/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0459 - categorical_accuracy: 0.7227 - val_loss: 0.0470 - val_categorical_accuracy: 0.7266
# Epoch 53/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0459 - categorical_accuracy: 0.7240 - val_loss: 0.0471 - val_categorical_accuracy: 0.7244
# Epoch 54/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0457 - categorical_accuracy: 0.7246 - val_loss: 0.0473 - val_categorical_accuracy: 0.7178
# Epoch 55/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0455 - categorical_accuracy: 0.7258 - val_loss: 0.0478 - val_categorical_accuracy: 0.7253
# Epoch 56/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0454 - categorical_accuracy: 0.7272 - val_loss: 0.0474 - val_categorical_accuracy: 0.7240
# Epoch 57/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0451 - categorical_accuracy: 0.7291 - val_loss: 0.0469 - val_categorical_accuracy: 0.7319
# Epoch 58/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0449 - categorical_accuracy: 0.7299 - val_loss: 0.0466 - val_categorical_accuracy: 0.7265
# Epoch 59/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0448 - categorical_accuracy: 0.7306 - val_loss: 0.0469 - val_categorical_accuracy: 0.7207
# Epoch 60/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0446 - categorical_accuracy: 0.7323 - val_loss: 0.0463 - val_categorical_accuracy: 0.7317
# Epoch 61/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0445 - categorical_accuracy: 0.7338 - val_loss: 0.0461 - val_categorical_accuracy: 0.7242
# Epoch 62/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0443 - categorical_accuracy: 0.7353 - val_loss: 0.0462 - val_categorical_accuracy: 0.7317
# Epoch 63/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0442 - categorical_accuracy: 0.7357 - val_loss: 0.0459 - val_categorical_accuracy: 0.7298
# Epoch 64/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0440 - categorical_accuracy: 0.7379 - val_loss: 0.0465 - val_categorical_accuracy: 0.7369
# Epoch 65/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0439 - categorical_accuracy: 0.7386 - val_loss: 0.0461 - val_categorical_accuracy: 0.7332
# Epoch 66/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0437 - categorical_accuracy: 0.7409 - val_loss: 0.0454 - val_categorical_accuracy: 0.7422
# Epoch 67/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0435 - categorical_accuracy: 0.7424 - val_loss: 0.0453 - val_categorical_accuracy: 0.7415
# Epoch 68/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0433 - categorical_accuracy: 0.7451 - val_loss: 0.0450 - val_categorical_accuracy: 0.7495
# Epoch 69/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0431 - categorical_accuracy: 0.7459 - val_loss: 0.0451 - val_categorical_accuracy: 0.7440
# Epoch 70/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0429 - categorical_accuracy: 0.7480 - val_loss: 0.0458 - val_categorical_accuracy: 0.7402
# Epoch 71/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0428 - categorical_accuracy: 0.7497 - val_loss: 0.0452 - val_categorical_accuracy: 0.7521
# Epoch 72/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0425 - categorical_accuracy: 0.7524 - val_loss: 0.0450 - val_categorical_accuracy: 0.7474
# Epoch 73/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0424 - categorical_accuracy: 0.7553 - val_loss: 0.0444 - val_categorical_accuracy: 0.7543
# Epoch 74/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0421 - categorical_accuracy: 0.7576 - val_loss: 0.0448 - val_categorical_accuracy: 0.7453
# Epoch 75/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0419 - categorical_accuracy: 0.7609 - val_loss: 0.0435 - val_categorical_accuracy: 0.7628
# Epoch 76/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0415 - categorical_accuracy: 0.7641 - val_loss: 0.0435 - val_categorical_accuracy: 0.7534
# Epoch 77/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0412 - categorical_accuracy: 0.7664 - val_loss: 0.0434 - val_categorical_accuracy: 0.7612
# Epoch 78/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0410 - categorical_accuracy: 0.7697 - val_loss: 0.0435 - val_categorical_accuracy: 0.7646
# Epoch 79/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0408 - categorical_accuracy: 0.7723 - val_loss: 0.0447 - val_categorical_accuracy: 0.7479
# Epoch 80/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0405 - categorical_accuracy: 0.7743 - val_loss: 0.0423 - val_categorical_accuracy: 0.7741
# Epoch 81/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0400 - categorical_accuracy: 0.7789 - val_loss: 0.0420 - val_categorical_accuracy: 0.7839
# Epoch 82/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0398 - categorical_accuracy: 0.7808 - val_loss: 0.0430 - val_categorical_accuracy: 0.7623
# Epoch 83/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0395 - categorical_accuracy: 0.7845 - val_loss: 0.0413 - val_categorical_accuracy: 0.7824
# Epoch 84/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0392 - categorical_accuracy: 0.7856 - val_loss: 0.0418 - val_categorical_accuracy: 0.7695
# Epoch 85/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0389 - categorical_accuracy: 0.7887 - val_loss: 0.0412 - val_categorical_accuracy: 0.7815
# Epoch 86/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0386 - categorical_accuracy: 0.7910 - val_loss: 0.0413 - val_categorical_accuracy: 0.7849
# Epoch 87/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0381 - categorical_accuracy: 0.7943 - val_loss: 0.0412 - val_categorical_accuracy: 0.7791
# Epoch 88/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0380 - categorical_accuracy: 0.7962 - val_loss: 0.0398 - val_categorical_accuracy: 0.7974
# Epoch 89/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0377 - categorical_accuracy: 0.7975 - val_loss: 0.0402 - val_categorical_accuracy: 0.7975
# Epoch 90/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0375 - categorical_accuracy: 0.7995 - val_loss: 0.0411 - val_categorical_accuracy: 0.7807
# Epoch 91/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0373 - categorical_accuracy: 0.8014 - val_loss: 0.0391 - val_categorical_accuracy: 0.8019
# Epoch 92/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0369 - categorical_accuracy: 0.8043 - val_loss: 0.0395 - val_categorical_accuracy: 0.8019
# Epoch 93/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0367 - categorical_accuracy: 0.8059 - val_loss: 0.0393 - val_categorical_accuracy: 0.8002
# Epoch 94/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0364 - categorical_accuracy: 0.8080 - val_loss: 0.0391 - val_categorical_accuracy: 0.8005
# Epoch 95/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0364 - categorical_accuracy: 0.8083 - val_loss: 0.0384 - val_categorical_accuracy: 0.8096
# Epoch 96/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0361 - categorical_accuracy: 0.8100 - val_loss: 0.0384 - val_categorical_accuracy: 0.8072
# Epoch 97/100
# 309847/309847 [==============================] - 2s 8us/sample - loss: 0.0360 - categorical_accuracy: 0.8113 - val_loss: 0.0386 - val_categorical_accuracy: 0.8017
# Epoch 98/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0356 - categorical_accuracy: 0.8135 - val_loss: 0.0388 - val_categorical_accuracy: 0.8031
# Epoch 99/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0357 - categorical_accuracy: 0.8146 - val_loss: 0.0380 - val_categorical_accuracy: 0.8113
# Epoch 100/100
# 309847/309847 [==============================] - 2s 7us/sample - loss: 0.0355 - categorical_accuracy: 0.8153 - val_loss: 0.0388 - val_categorical_accuracy: 0.8050

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# plot loss vs epoch
plt.figure(figsize=(15,10))
ax = plt.subplot(2, 2, 1)
ax.plot(history.history['loss'], label='loss')
ax.plot(history.history['val_loss'], label='val_loss')
ax.legend(loc="upper right")
ax.set_xlabel('epoch')
ax.set_ylabel('loss')

# plot accuracy vs epoch
ax = plt.subplot(2, 2, 2)
ax.plot(history.history['categorical_accuracy'], label='acc')
ax.plot(history.history['val_categorical_accuracy'], label='val_acc')
ax.legend(loc="upper left")
ax.set_xlabel('epoch')
ax.set_ylabel('acc')

# %%
results = model.evaluate(signal_test[vars_test], signal_test[vars_check])
print results
# Out:
# 203483/203483 [==============================] - 3s 16us/sample - loss: 0.4223 - categorical_accuracy: 0.8057
# [0.42228811842235625, 0.8057037]

# %%
#Save model
model.save("ZSelector_model_mass_test.h5")

# %%
from tensorflow.python.keras.models import load_model
ZSelector = load_model('ZSelector_model_mass_test.h5')
# Out:
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor
# WARNING:tensorflow:From /home/nikmenendez/.local/lib/python2.7/site-packages/tensorflow/python/ops/init_ops.py:97: calling __init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
from __future__ import division
from tqdm import tqdm

# %%
input_files = ['/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

#vars_in = list(set(vars_in))

#print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]

signal = min_max_scaling(signal)

results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print "15 GeV Results:"
print results

cat0 = len(signal[(signal['c0'] == 1)])
cat1 = len(signal[(signal['c1'] == 1)])
cat2 = len(signal[(signal['c2'] == 1)])
cat3 = len(signal[(signal['c3'] == 1)])
tot = len(signal)
print "cat0 = %f, cat1 = %f, cat2 = %f, cat3 = %f" % (cat0/tot, cat1/tot, cat2/tot, cat3/tot)

cat0_cor = 0.
cat1_cor = 0.
cat2_cor = 0.
cat3_cor = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(signal.index)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: cat0_cor+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: cat1_cor+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: cat2_cor+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: cat3_cor+=1
    
print "cat0_correct = %f, cat1_correct = %f, cat2_correct = %f, cat3_correct = %f" % (cat0_cor/cat0, cat1_cor/cat1, cat2_cor/cat2, cat3_cor/cat3)
# Out:
# 71000/71000 [==============================] - 1s 16us/sample - loss: 0.3185 - categorical_accuracy: 0.8902
# 15 GeV Results:
# [0.3185104483987244, 0.8902113]
# cat0 = 0.004239, cat1 = 0.062577, cat2 = 0.192085, cat3 = 0.741099
# cat0_correct = 0.079734, cat1_correct = 0.452847, cat2_correct = 0.779806, cat3_correct = 0.960394

# %%
input_files = [#'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

#vars_in = list(set(vars_in))

#print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]

signal = min_max_scaling(signal)

results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print "20 GeV Results:"
print results

cat0 = len(signal[(signal['c0'] == 1)])
cat1 = len(signal[(signal['c1'] == 1)])
cat2 = len(signal[(signal['c2'] == 1)])
cat3 = len(signal[(signal['c3'] == 1)])
tot = len(signal)
print "cat0 = %f, cat1 = %f, cat2 = %f, cat3 = %f" % (cat0/tot, cat1/tot, cat2/tot, cat3/tot)

cat0_cor = 0.
cat1_cor = 0.
cat2_cor = 0.
cat3_cor = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(signal.index)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: cat0_cor+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: cat1_cor+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: cat2_cor+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: cat3_cor+=1
    
print "cat0_correct = %f, cat1_correct = %f, cat2_correct = %f, cat3_correct = %f" % (cat0_cor/cat0, cat1_cor/cat1, cat2_cor/cat2, cat3_cor/cat3)
# Out:
# 79999/79999 [==============================] - 1s 16us/sample - loss: 0.3462 - categorical_accuracy: 0.8698
# 20 GeV Results:
# [0.3461674492348492, 0.86983585]
# cat0 = 0.001100, cat1 = 0.052951, cat2 = 0.204990, cat3 = 0.740959
# cat0_correct = 0.034091, cat1_correct = 0.441926, cat2_correct = 0.833587, cat3_correct = 0.911684

# %%
input_files = [#'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

#vars_in = list(set(vars_in))

#print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]

signal = min_max_scaling(signal)

results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print "30 GeV Results:"
print results

cat0 = len(signal[(signal['c0'] == 1)])
cat1 = len(signal[(signal['c1'] == 1)])
cat2 = len(signal[(signal['c2'] == 1)])
cat3 = len(signal[(signal['c3'] == 1)])
tot = len(signal)
print "cat0 = %f, cat1 = %f, cat2 = %f, cat3 = %f" % (cat0/tot, cat1/tot, cat2/tot, cat3/tot)

cat0_cor = 0.
cat1_cor = 0.
cat2_cor = 0.
cat3_cor = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(signal.index)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: cat0_cor+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: cat1_cor+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: cat2_cor+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: cat3_cor+=1
    
print "cat0_correct = %f, cat1_correct = %f, cat2_correct = %f, cat3_correct = %f" % (cat0_cor/cat0, cat1_cor/cat1, cat2_cor/cat2, cat3_cor/cat3)
# Out:
# 117356/117356 [==============================] - 2s 16us/sample - loss: 0.5558 - categorical_accuracy: 0.7297
# 30 GeV Results:
# [0.5558111145729269, 0.7296772]
# cat0 = 0.000639, cat1 = 0.122567, cat2 = 0.413187, cat3 = 0.463606
# cat0_correct = 0.013333, cat1_correct = 0.303601, cat2_correct = 0.752671, cat3_correct = 0.822817

# %%
input_files = [#'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

#vars_in = list(set(vars_in))

#print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]

signal = min_max_scaling(signal)

results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print "45 GeV Results:"
print results

cat0 = len(signal[(signal['c0'] == 1)])
cat1 = len(signal[(signal['c1'] == 1)])
cat2 = len(signal[(signal['c2'] == 1)])
cat3 = len(signal[(signal['c3'] == 1)])
tot = len(signal)
print "cat0 = %f, cat1 = %f, cat2 = %f, cat3 = %f" % (cat0/tot, cat1/tot, cat2/tot, cat3/tot)

cat0_cor = 0.
cat1_cor = 0.
cat2_cor = 0.
cat3_cor = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(signal.index)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: cat0_cor+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: cat1_cor+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: cat2_cor+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: cat3_cor+=1
    
print "cat0_correct = %f, cat1_correct = %f, cat2_correct = %f, cat3_correct = %f" % (cat0_cor/cat0, cat1_cor/cat1, cat2_cor/cat2, cat3_cor/cat3)
# Out:
# 165121/165121 [==============================] - 3s 16us/sample - loss: 0.5848 - categorical_accuracy: 0.6939
# 45 GeV Results:
# [0.584776335617551, 0.69393355]
# cat0 = 0.000224, cat1 = 0.574161, cat2 = 0.304940, cat3 = 0.120675
# cat0_correct = 0.054054, cat1_correct = 0.724690, cat2_correct = 0.651533, cat3_correct = 0.655927

# %%
input_files = [#'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WpTo3l_ZpM60_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM15_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM20_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM30_PS.root',
               #'/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM45_PS.root',
               '/cmsuf/data/store/user/t2/users/nikmenendez/skimmed/signal/MVA/WmTo3l_ZpM60_PS.root'
               ]
treename = 'passedEvents'

#vars_in = list(set(vars_in))

#print "... Opening input files:"

arrs_sig = [None]*(len(input_files))

#print "Opening file: ",input_files[0]
arrs_sig[0] = uproot.open(input_files[0])[treename]
signal = arrs_sig[0].pandas.df(vars_in)

for i in range(1,len(input_files)):
    #print "Opening file: ", input_files[i]
    arrs_sig[i] = uproot.open(input_files[i])[treename]
    temp_sig = arrs_sig[i].pandas.df(vars_in)
    signal = signal.append(temp_sig)
    
#print signal[vars_in]

signal = min_max_scaling(signal)

results = ZSelector.evaluate(signal[vars_test], signal[vars_check])
print "60 GeV Results:"
print results

cat0 = len(signal[(signal['c0'] == 1)])
cat1 = len(signal[(signal['c1'] == 1)])
cat2 = len(signal[(signal['c2'] == 1)])
cat3 = len(signal[(signal['c3'] == 1)])
tot = len(signal)
print "cat0 = %f, cat1 = %f, cat2 = %f, cat3 = %f" % (cat0/tot, cat1/tot, cat2/tot, cat3/tot)

cat0_cor = 0.
cat1_cor = 0.
cat2_cor = 0.
cat3_cor = 0.
prediction_0 = ZSelector.predict(signal[vars_test])
for q in range(len(signal.index)):
    max_guess = 0
    guess_slot = 0
    for i in range(len(prediction_0[q])):
        if prediction_0[q][i] > max_guess:
            max_guess = prediction_0[q][i]
            guess_slot = i
    if guess_slot == 0:
        if signal['c0'].iloc[q] == 1: cat0_cor+=1
    if guess_slot == 1:
        if signal['c1'].iloc[q] == 1: cat1_cor+=1
    if guess_slot == 2:
        if signal['c2'].iloc[q] == 1: cat2_cor+=1
    if guess_slot == 3:
        if signal['c3'].iloc[q] == 1: cat3_cor+=1
    
print "cat0_correct = %.2f, cat1_correct = %.2f, cat2_correct = %.2f, cat3_correct = %.2f" % (cat0_cor/cat0, cat1_cor/cat1, cat2_cor/cat2, cat3_cor/cat3)
# Out:
# 177946/177946 [==============================] - 3s 16us/sample - loss: 0.2466 - categorical_accuracy: 0.9038
# 60 GeV Results:
# [0.24663321407644537, 0.903791]
# cat0 = 0.000259, cat1 = 0.582587, cat2 = 0.189355, cat3 = 0.227799
# cat0_correct = 0.09, cat1_correct = 0.90, cat2_correct = 0.86, cat3_correct = 0.94
